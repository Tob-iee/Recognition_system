# %% [markdown]
# ### STEP 1: Label the image
#
# You can label the image using labelimg
#
# labelimg is not a premade model so you have to install it using pip. Just type
# _pip install labelimg_
#
# Then just type Labelimg on your command line

# %%
# %%bash

# %%
import tarfile

path
